# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install spotipy --upgrade
# Out:
# ...
#   Attempting uninstall: spotipy
#     Found existing installation: spotipy 2.25.1
#     Uninstalling spotipy-2.25.1:
#       Successfully uninstalled spotipy-2.25.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id = 'a420a1c056564e0794f3681fa6a5f2d4', client_secret = 'e3eb19ceb5f24b2bb2e8fe6f0f354275')
sp = spotipy.Spotify(client_credentials_manager=auth_manager)

url = 'https://open.spotify.com/playlist/40WMGBhEAUFf4lqEtP6oG9'

# %%
url.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '40WMGBhEAUFf4lqEtP6oG9']

# %%
playlist_uri = url.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/40WMGBhEAUFf4lqEtP6oG9/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-11-04T03:55:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31fo4jholshngjqgiraxhirdgyge'},
#     'href': 'https://api.spotify.com/v1/users/31fo4jholshngjqgiraxhirdgyge',
#     'id': '31fo4jholshngjqgiraxhirdgyge',
#     'type': 'user',
#     'uri': 'spotify:user:31fo4jholshngjqgiraxhirdgyge'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
# ...

# %%
len(data['items'])
# Out:
# 13

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['added_at']
# Out:
# '2025-11-04T03:55:07Z'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
# ...

# %%
album = []
for item in data['items']:
    album_id = item['track']['album']['id']
    album_name = item['track']['album']['name']
    album_release_date = item['track']['album']['release_date']
    album_ext_url = item['track']['album']['external_urls']['spotify']
    album.append({'album_id':album_id,
                 'album_name':album_name,
                  'album_release_date':album_release_date,
                  'album_ext_url':album_ext_url
        })

# %%
import pandas as pd

# %%
album
# Out:
# [{'album_id': '7fJJK56U9fHixgO0HQkhtI',
#   'album_name': 'Future Nostalgia',
#   'album_release_date': '2020-03-27',
#   'album_ext_url': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#  {'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_release_date': '2002-05-09',
#   'album_ext_url': 'https://open.spotify.com/album/5e1sQOcB4PnyMXxQ6BMZJf'},
#  {'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_release_date': '2002-05-09',
#   'album_ext_url': 'https://open.spotify.com/album/5e1sQOcB4PnyMXxQ6BMZJf'},
#  {'album_id': '6cYYhBXFQlwaD1mqQv9x0W',
#   'album_name': 'Nuvve Nuvve',
#   'album_release_date': '2002-09-10',
#   'album_ext_url': 'https://open.spotify.com/album/6cYYhBXFQlwaD1mqQv9x0W'},
#  {'album_id': '14y2SFcCjBang1kBi6eZto',
#   'album_name': 'Yamudu',
#   'album_release_date': '2013-01-15',
#   'album_ext_url': 'https://open.spotify.com/album/14y2SFcCjBang1kBi6eZto'},
# ...

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
auth_manager = SpotifyClientCredentials(client_id = "a420a1c056564e0794f3681fa6a5f2d4", client_secret = "e3eb19ceb5f24b2bb2e8fe6f0f354275")

# %%
sp = spotipy.Spotify(auth_manager = auth_manager)

# %%
url = "https://open.spotify.com/playlist/40WMGBhEAUFf4lqEtP6oG9"

# %%
playlist_uri = url.split("/")[-1]

# %%
data = sp.playlist(playlist_uri)

# %%
data['tracks']['items'][0]['track']['album']['id']
data['tracks']['items'][0]['track']['album']['name']
data['tracks']['items'][0]['track']['album']['release_date']
data['tracks']['items'][0]['track']['album']['external_urls']['spotify']
data['tracks']['items'][0]['track']['id']
data
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/40WMGBhEAUFf4lqEtP6oG9'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/40WMGBhEAUFf4lqEtP6oG9?additional_types=track',
#  'id': '40WMGBhEAUFf4lqEtP6oG9',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e0225499fba554ca7d4b166dc70ab67616d00001e0246a2e185980b082e503f4212ab67616d00001e02a33c8fc106087d93fd346010ab67616d00001e02c88bae7846e62a8ba59ee0bd',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e0225499fba554ca7d4b166dc70ab67616d00001e0246a2e185980b082e503f4212ab67616d00001e02a33c8fc106087d93fd346010ab67616d00001e02c88bae7846e62a8ba59ee0bd',
#    'width': 300},
#   {'height': 60,
# ...

# %%
album_list = []
for item in data['tracks']['items']:
    album_id = item['track']['album']['id']
    album_name = item['track']['album']['name']
    album_ReleaseDate = item['track']['album']['release_date']
    addedto_playlist = item['added_at']
    playlist_user_id = item['added_by']['id']
    Song_id = item['track']['id']
    album_list.append({'playlist_user_id':playlist_user_id,'album_id':album_id,'album_name':album_name,'album_ReleaseDate':album_ReleaseDate,'addedto_playlist':addedto_playlist,'Song_id':Song_id})

# %%
album_list
# Out:
# [{'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '7fJJK56U9fHixgO0HQkhtI',
#   'album_name': 'Future Nostalgia',
#   'album_ReleaseDate': '2020-03-27',
#   'addedto_playlist': '2025-11-04T03:55:07Z',
#   'Song_id': '39LLxExYz6ewLAcYrzQQyP'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_ReleaseDate': '2002-05-09',
#   'addedto_playlist': '2025-11-04T03:56:35Z',
#   'Song_id': '5bRsCXzjpkjDXmVGkgfL4w'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_ReleaseDate': '2002-05-09',
#   'addedto_playlist': '2025-11-04T03:56:44Z',
#   'Song_id': '5fCa6flkbfFHbzFt62tW7p'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '6cYYhBXFQlwaD1mqQv9x0W',
#   'album_name': 'Nuvve Nuvve',
#   'album_ReleaseDate': '2002-09-10',
# ...

# %%
#data['tracks']['items'][-1]['track']['artists'][0]['name']
Song_artists = []
for item in data['tracks']['items']:
    song_id = item['track']['id']
    for artist in item['track']['artists']:
        artist_id = artist['id']
        artist_name = artist['name']
        
        Song_artists.append({'song_id':song_id,'artist_id':artist_id,'artist_name':artist_name})

# %%
Songdetails = []
for item in data['tracks']['items']:
    Song_id = item['track']['id']
    Song_name = item['track']['name']
    Song_popularity = item['track']['popularity']
    Song_duration_ms = item['track']['duration_ms']
    Songdetails.append({'Song_id':Song_id,'Song_name':Song_name,'Song_popularity':Song_popularity,'Song_duration_ms':Song_duration_ms})

# %%
Song_artists
# Out:
# [{'song_id': '39LLxExYz6ewLAcYrzQQyP',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa'},
#  {'song_id': '5bRsCXzjpkjDXmVGkgfL4w',
#   'artist_id': '3ZuUs3HhXssOQ3mt9WpBfw',
#   'artist_name': 'Usha Munukutla'},
#  {'song_id': '5fCa6flkbfFHbzFt62tW7p',
#   'artist_id': '6aQ5LDX0WlnyDLI8TGU0wK',
#   'artist_name': 'Rajesh'},
#  {'song_id': '30MixFD08OXoFZkeA4INK7',
#   'artist_id': '6RO7sGAsA3D9HjYUQdEYnM',
#   'artist_name': 'Koti'},
#  {'song_id': '30MixFD08OXoFZkeA4INK7',
#   'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK'},
#  {'song_id': '6oRSIMbiGP1IZ63baI3N5l',
#   'artist_id': '4l9RrGw4skP0OjeNdolWqD',
#   'artist_name': 'Suchithra Karthik Kumar'},
#  {'song_id': '0LMvYrD1JpHavQcyRoSaqZ',
#   'artist_id': '3NzhVoa20crNtp1p4zE8um',
#   'artist_name': 'Mano'},
#  {'song_id': '0LMvYrD1JpHavQcyRoSaqZ',
#   'artist_id': '2Ah48tA0TPqph0m9snNNxM',
#   'artist_name': 'Gayathri'},
#  {'song_id': '1TQV1n9z8zdeD8761wsJUZ',
# ...

# %%
album_list
# Out:
# [{'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '7fJJK56U9fHixgO0HQkhtI',
#   'album_name': 'Future Nostalgia',
#   'album_ReleaseDate': '2020-03-27',
#   'addedto_playlist': '2025-11-04T03:55:07Z',
#   'Song_id': '39LLxExYz6ewLAcYrzQQyP'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_ReleaseDate': '2002-05-09',
#   'addedto_playlist': '2025-11-04T03:56:35Z',
#   'Song_id': '5bRsCXzjpkjDXmVGkgfL4w'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '5e1sQOcB4PnyMXxQ6BMZJf',
#   'album_name': 'Santhosham',
#   'album_ReleaseDate': '2002-05-09',
#   'addedto_playlist': '2025-11-04T03:56:44Z',
#   'Song_id': '5fCa6flkbfFHbzFt62tW7p'},
#  {'playlist_user_id': '31fo4jholshngjqgiraxhirdgyge',
#   'album_id': '6cYYhBXFQlwaD1mqQv9x0W',
#   'album_name': 'Nuvve Nuvve',
#   'album_ReleaseDate': '2002-09-10',
# ...

# %%
Song_artists
# Out:
# [{'song_id': '39LLxExYz6ewLAcYrzQQyP', 'artist_name': 'Dua Lipa'},
#  {'song_id': '5bRsCXzjpkjDXmVGkgfL4w', 'artist_name': 'Usha Munukutla'},
#  {'song_id': '5fCa6flkbfFHbzFt62tW7p', 'artist_name': 'Rajesh'},
#  {'song_id': '30MixFD08OXoFZkeA4INK7', 'artist_name': 'Koti'},
#  {'song_id': '30MixFD08OXoFZkeA4INK7', 'artist_name': 'KK'},
#  {'song_id': '6oRSIMbiGP1IZ63baI3N5l',
#   'artist_name': 'Suchithra Karthik Kumar'},
#  {'song_id': '0LMvYrD1JpHavQcyRoSaqZ', 'artist_name': 'Mano'},
#  {'song_id': '0LMvYrD1JpHavQcyRoSaqZ', 'artist_name': 'Gayathri'},
#  {'song_id': '1TQV1n9z8zdeD8761wsJUZ', 'artist_name': 'G. V. Prakash'},
#  {'song_id': '1TQV1n9z8zdeD8761wsJUZ', 'artist_name': 'Siddharth'},
#  {'song_id': '1TQV1n9z8zdeD8761wsJUZ', 'artist_name': 'Saindhavi'},
#  {'song_id': '0MU4LT5akvYfbRKXBfBlPY',
#   'artist_name': 'Sunitha Saradhi Febimani'},
#  {'song_id': '1UiORBsodWhAydO2SjQyei', 'artist_name': 'Ilaiyaraaja'},
# ...

# %%
import pandas as pd

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                playlist_user_id                album_id        album_name  \
# 0  31fo4jholshngjqgiraxhirdgyge  7fJJK56U9fHixgO0HQkhtI  Future Nostalgia
# 1  31fo4jholshngjqgiraxhirdgyge  5e1sQOcB4PnyMXxQ6BMZJf        Santhosham
# 2  31fo4jholshngjqgiraxhirdgyge  5e1sQOcB4PnyMXxQ6BMZJf        Santhosham
# 3  31fo4jholshngjqgiraxhirdgyge  6cYYhBXFQlwaD1mqQv9x0W       Nuvve Nuvve
# 4  31fo4jholshngjqgiraxhirdgyge  14y2SFcCjBang1kBi6eZto            Yamudu
#
#   album_ReleaseDate      addedto_playlist                 Song_id
# 0        2020-03-27  2025-11-04T03:55:07Z  39LLxExYz6ewLAcYrzQQyP
# 1        2002-05-09  2025-11-04T03:56:35Z  5bRsCXzjpkjDXmVGkgfL4w
# 2        2002-05-09  2025-11-04T03:56:44Z  5fCa6flkbfFHbzFt62tW7p
# 3        2002-09-10  2025-11-12T09:41:58Z  30MixFD08OXoFZkeA4INK7
# 4        2013-01-15  2025-11-12T09:41:59Z  6oRSIMbiGP1IZ63baI3N5l

# %%
Song_df = pd.DataFrame.from_dict(Songdetails)

# %%
Song_df.head()
# Out:
#                   Song_id        Song_name  Song_popularity  Song_duration_ms
# 0  39LLxExYz6ewLAcYrzQQyP       Levitating               80            203807
# 1  5bRsCXzjpkjDXmVGkgfL4w  Nee Tholisariga               52            290966
# 2  5fCa6flkbfFHbzFt62tW7p    Emainadho Emo               43            116550
# 3  30MixFD08OXoFZkeA4INK7  I Am Very Sorry               50            342700
# 4  6oRSIMbiGP1IZ63baI3N5l     Naa Hrudayam               41            273066

# %%
Song_artist_df = pd.DataFrame.from_dict(Song_artists)

# %%
Song_artist_df.head()
# Out:
#                   song_id               artist_id     artist_name
# 0  39LLxExYz6ewLAcYrzQQyP  6M2wZ9GZgrQXHCFfjv46we        Dua Lipa
# 1  5bRsCXzjpkjDXmVGkgfL4w  3ZuUs3HhXssOQ3mt9WpBfw  Usha Munukutla
# 2  5fCa6flkbfFHbzFt62tW7p  6aQ5LDX0WlnyDLI8TGU0wK          Rajesh
# 3  30MixFD08OXoFZkeA4INK7  6RO7sGAsA3D9HjYUQdEYnM            Koti
# 4  30MixFD08OXoFZkeA4INK7  4fEkbug6kZzzJ8eYX6Kbbp              KK

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   playlist_user_id   13 non-null     object
#  1   album_id           13 non-null     object
#  2   album_name         13 non-null     object
#  3   album_ReleaseDate  13 non-null     datetime64[ns]
#  4   addedto_playlist   13 non-null     datetime64[ns, UTC]
#  5   Song_id            13 non-null     object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), object(4)
# memory usage: 756.0+ bytes

# %%
album_df['album_ReleaseDate'] = pd.to_datetime(album_df['album_ReleaseDate'])

# %%
album_df['addedto_playlist'] = pd.to_datetime(album_df['addedto_playlist'])

# %%
album_df.head()
# Out:
#                playlist_user_id                album_id        album_name  \
# 0  31fo4jholshngjqgiraxhirdgyge  7fJJK56U9fHixgO0HQkhtI  Future Nostalgia
# 1  31fo4jholshngjqgiraxhirdgyge  5e1sQOcB4PnyMXxQ6BMZJf        Santhosham
# 2  31fo4jholshngjqgiraxhirdgyge  5e1sQOcB4PnyMXxQ6BMZJf        Santhosham
# 3  31fo4jholshngjqgiraxhirdgyge  6cYYhBXFQlwaD1mqQv9x0W       Nuvve Nuvve
# 4  31fo4jholshngjqgiraxhirdgyge  14y2SFcCjBang1kBi6eZto            Yamudu
#
#   album_ReleaseDate          addedto_playlist                 Song_id
# 0        2020-03-27 2025-11-04 03:55:07+00:00  39LLxExYz6ewLAcYrzQQyP
# 1        2002-05-09 2025-11-04 03:56:35+00:00  5bRsCXzjpkjDXmVGkgfL4w
# 2        2002-05-09 2025-11-04 03:56:44+00:00  5fCa6flkbfFHbzFt62tW7p
# 3        2002-09-10 2025-11-12 09:41:58+00:00  30MixFD08OXoFZkeA4INK7
# 4        2013-01-15 2025-11-12 09:41:59+00:00  6oRSIMbiGP1IZ63baI3N5l

# %%
from datetime import datetime

# %%
print(datetime.now())
# Out:
# 2026-02-24 16:16:13.740508

# %%
print(data.keys())
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'items', 'type', 'uri'])

# %%
data
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/40WMGBhEAUFf4lqEtP6oG9'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/40WMGBhEAUFf4lqEtP6oG9?additional_types=track',
#  'id': '40WMGBhEAUFf4lqEtP6oG9',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e0225499fba554ca7d4b166dc70ab67616d00001e0246a2e185980b082e503f4212ab67616d00001e02a33c8fc106087d93fd346010ab67616d00001e02c88bae7846e62a8ba59ee0bd',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e0225499fba554ca7d4b166dc70ab67616d00001e0246a2e185980b082e503f4212ab67616d00001e02a33c8fc106087d93fd346010ab67616d00001e02c88bae7846e62a8ba59ee0bd',
#    'width': 300},
#   {'height': 60,
# ...

# %%
data['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
url = 'https://programmer100.pythonanywhere.com/'

# %%
import requests

# %%
response = requests.get(url)

# %%
data = response.text

# %%
data
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <title>PythonHow App | \n\tHome\n</title>\n    <!-- Font Awesome -->\n    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css">\n    <!-- Bootstrap core CSS -->\n    <link href="/static/css/bootstrap.min.css" rel="stylesheet">\n    <!-- Material Design Bootstrap -->\n    <link href="/static/css/mdb.min.css" rel="stylesheet">\n    <!-- Your custom styles (optional) -->\n    <link href="/static/css/style.css" rel="stylesheet">\n  </head>\n\n  <body>\n\n    \n      <!--Navbar-->\n<nav class="navbar navbar-expand-lg navbar-dark secondary-color mb-5">\n\n<div class="container">\n    <!-- Navbar brand -->\n    <a class="navbar-brand" href="/">Home</a>\n\n    <!-- Collapse button -->\n    <button class="navbar
# ...
