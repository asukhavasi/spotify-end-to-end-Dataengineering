# %%
print("Hello Abilash")
# Out:
# Hello Abilash

# %%
name = 'Abilash'

# %%
len(name)
# Out:
# 7

# %%
name[0:7]
# Out:
# 'Abilash'

# %%
name[-5::]
# Out:
# 'ilash'

# %%
firstname = 'Abilash'
lastname = 'Sukhavasi'

# %%
fullname = firstname +' '+ lastname
print(fullname)
# Out:
# Abilash Sukhavasi

# %%
fullname[-3:]
# Out:
# 'asi'

# %% [markdown]
# DataStructures

# %%
#Lists

# %%
mylists = [1,2,3,4]
mylists[3]
# Out:
# 4

# %%
my_list1 = [1,2.2,'abc']

# %%
len(my_list1)
# Out:
# 3

# %%
my_list1.append(2)

# %%
my_list1.extend([7,8,10])

# %%
my_list1
# Out:
# [1, 2.2, 'abc', 2, 7, 8, 10]

# %%
my_list2 = list(range(11))

# %%
#print alternate numbers starting from 1 to 9
alternatenumbers = my_list2[1:10:2]
#print alternate numbers from 0 to 10
even = my_list2[0::2]

# %%
even
# Out:
# [0, 2, 4, 6, 8, 10]

# %% [markdown]
# Dictionary

# %%
my_dict = {"key1":"Value1","Key2":"value2"}

# %%
my_dict
# Out:
# {'key1': 'Value1', 'Key2': 'value2'}

# %% [markdown]
# Sets

# %%
my_set = {1,2,3}

# %%
type(my_set)
# Out:
# set

# %%
my_set.add(4)

# %%
my_set
# Out:
# {1, 2, 3, 4}

# %%
my_set.remove(3)

# %%
my_set
# Out:
# {1, 2, 4}

# %% [markdown]
# Tuple

# %%
my_tup1 = (1,2,1,2)

# %%
type(my_tup1)
# Out:
# tuple

# %%
len(my_tup1)
# Out:
# 4

# %%
#can be indexed and sliced
